# %%
#Import Libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

#set default figure size
matplotlib.rcParams['figure.figsize'] = (12,8)

#Read in the data
df=pd.read_csv("movies.csv")

# %%
#Data preview

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#check for missing values

for col in df.columns:
    pct_missing = np.mean(df[col].isnull()) * 100  # Convert to percentage
    print(f'{col} - {pct_missing:.2f}%')  # Format to 2 decimal places
# Out:
# name - 0.00%
# rating - 1.00%
# genre - 0.00%
# year - 0.00%
# released - 0.03%
# score - 0.04%
# votes - 0.04%
# director - 0.00%
# writer - 0.04%
# star - 0.01%
# country - 0.04%
# budget - 28.31%
# gross - 2.46%
# company - 0.22%
# runtime - 0.05%

# %%
#Drop rows with missing vaues
df= df.dropna()  # Removes all rows with any NaN values
print(df.isnull().values.any())  # Returns True if there are still missing values
# Out:
# False

# %%
#Data types of the columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Change data type of columns

df['budget']=df['budget'].astype('int64')
df['gross']=df['gross'].astype('int64')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Creating a new column called released_year from released column, as year column contains incorrect data

# Extract the year from the 'released' column
df['released_year'] = df['released'].str.extract(r'(\d{4})')

# Convert the 'released_year' column to numeric (int)
df['released_year'] = pd.to_numeric(df['released_year'], errors='coerce')

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#Delete year column
df = df.drop('year', axis=1)

# %%
#sort values by gross
df.sort_values(by=['gross'], inplace=False, ascending=False).head()
# Out:
#                                             name rating   genre  \
# 5445                                      Avatar  PG-13  Action
# 7445                           Avengers: Endgame  PG-13  Action
# 3045                                     Titanic  PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action
# 7244                      Avengers: Infinity War  PG-13  Action
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Display all rows of the DataFrame
pd.set_option("display.max_rows", None)  # Remove the row limit

# %%
#Delete duplicates if there are any
df.drop_duplicates().head(10)
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
# 5                                 Friday the 13th      R     Horror
# 6                              The Blues Brothers      R     Action
# 7                                     Raging Bull      R  Biography
# 8                                     Superman II     PG     Action
# 9                                 The Long Riders      R  Biography
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
#Plot budget vs Gross earnings
plt.scatter(x=df['gross'], y=df['budget'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget')
plt.show()

# %%
#Plot budget vs gross earnings using seaborn

sns.regplot(x='gross', y='budget', data=df, scatter_kws={'color':'red'}, line_kws={'color':'blue'})
# Out:
# <Axes: xlabel='gross', ylabel='budget'>

# %%
#Correlation between numerical columns
#Correlation types: Pearson, Kendall, Spearman

# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=np.number)

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr(method='pearson')

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                   score     votes    budget     gross   runtime  released_year
# score          1.000000  0.474256  0.072001  0.222556  0.414068       0.061923
# votes          0.474256  1.000000  0.439675  0.614751  0.352303       0.203098
# budget         0.072001  0.439675  1.000000  0.740247  0.318695       0.320312
# gross          0.222556  0.614751  0.740247  1.000000  0.275796       0.268721
# runtime        0.414068  0.352303  0.318695  0.275796  1.000000       0.075294
# released_year  0.061923  0.203098  0.320312  0.268721  0.075294       1.000000

# %%
#View correlation through heat map

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for numeric columns')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Convert string columns to numeric to see the correlation btwn all columns

df_numerized = df.copy()
for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized
# Out:
#       name  rating  genre  released  score      votes  director  writer  star  \
# 0     4692       6      6      1304    8.4   927000.0      1795    2832   699
# 1     3929       6      1      1127    5.8    65000.0      1578    1158   214
# 2     3641       4      0      1359    8.7  1200000.0       757    1818  1157
# 3      204       4      4      1127    7.7   221000.0       889    1413  1474
# 4      732       6      4      1170    7.3   108000.0       719     351   271
# ...    ...     ...    ...       ...    ...        ...       ...     ...   ...
# 7648   415       6      0       904    6.6   140000.0        16    2390  1812
# 7649  3556       4      0       713    6.5   102000.0       852    2309   147
# 7650  1153       4      1       904    5.6    53000.0      1809    2827  1470
# 7651  3978       4      1       758    6.8    42000.0       294    2091   640
# 7652  4090       3      0       370    6.8     3700.0       746    1184  1839
#
# ...

# %%
# Correlation between all the coloumns
df_numerized.corr()
# Out:
#                    name    rating     genre  released     score     votes  \
# name           1.000000 -0.029234  0.010996 -0.006152  0.014450  0.012615
# rating        -0.029234  1.000000  0.147796  0.018083  0.065983  0.006031
# genre          0.010996  0.147796  1.000000  0.022142  0.035106 -0.135990
# released      -0.006152  0.018083  0.022142  1.000000  0.045874  0.028833
# score          0.014450  0.065983  0.035106  0.045874  1.000000  0.474256
# votes          0.012615  0.006031 -0.135990  0.028833  0.474256  1.000000
# director       0.015246  0.014656 -0.008553  0.002308  0.005413 -0.010376
# writer         0.012880 -0.003149  0.017578  0.008072  0.012843 -0.005316
# star          -0.006882  0.009196  0.003341  0.015706  0.007296 -0.017638
# country       -0.025490  0.008230 -0.009164 -0.017228 -0.043051  0.041551
# budget         0.023392 -0.203946 -0.368523  0.019952  0.072001  0.439675
# gross          0.005639 -0.181906 -0.244101  0.008501  0.222556  0.614751
# ...

# %%
# View Correlation between all the columns through  heat map

correlation_mat = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for all columns')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Compute correlation matrix
correlation_matx = df_numerized.corr()

#unstack the matrix into a series
corr_pairs = correlation_matx.unstack()

# sort the correlation pairs from highest to lowest
sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs
# Out:
# name      name        1.000000
# rating    rating      1.000000
# genre     genre       1.000000
# score     score       1.000000
# released  released    1.000000
#                         ...
# budget    rating     -0.203946
# gross     genre      -0.244101
# genre     gross      -0.244101
#           budget     -0.368523
# budget    genre      -0.368523
# Length: 225, dtype: float64

# %%
# filter for correlations above 0.5
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# name           name             1.000000
# rating         rating           1.000000
# genre          genre            1.000000
# score          score            1.000000
# released       released         1.000000
# votes          votes            1.000000
# director       director         1.000000
# star           star             1.000000
# writer         writer           1.000000
# gross          gross            1.000000
# company        company          1.000000
# released_year  released_year    1.000000
# runtime        runtime          1.000000
# country        country          1.000000
# budget         budget           1.000000
# gross          budget           0.740247
# budget         gross            0.740247
# votes          gross            0.614751
# gross          votes            0.614751
# dtype: float64
